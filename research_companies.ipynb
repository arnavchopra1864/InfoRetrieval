# %%
file = open('research_companies_raw.txt', 'r')

urls = []
while True:
	content=file.readline()
	if not content:
		break
	if content[:3] == "URL":
		urls.append(content[5:])

# %%
print(urls)

for url in urls:
    print(url[url.index("://")+3:])
# Out:
# ['https://www.aamc.org/ \n', 'http://aata.getty.edu/\n', 'http://www.academicjournals.org/about.htm \n', 'http://www.aera.net/Default.aspx?id=274 \n', 'http://agecon.lib.umn.edu/ \n', 'http://usain.org/agzines.html \n', 'http://www.aaai.org/Magazine/magazine.php \n', 'http://www.ajhs.org/reference/adaje.cfm\n', 'http://digitallibrary.amnh.org/dspace/ \n', 'http://www.aps.org/publications/index.cfm\n', 'http://apsjournals.apsnet.org/ \n', 'http://aslo.org/index.html \n', 'http://www.animalagriculture.org/Information/Publications.html \n', 'http://digital.lib.msu.edu/projects/africanjournals/ \n', 'http://arxiv.org/ \n', 'http://www.adb.org/Publications/title.asp\n', 'http://www.austlii.edu.au/au/journals/ \n', 'http://www.nla.gov.au/ferg/ \n', 'http://www.banglajol.info/ \n', 'http://www.bentham.org/open/index.htm \n', 'http://biodiversitylibrary.org/ \n', 'http://www.bioline.org.br/journals \n', 'http://www.biomedcentral.com/search/ \n', 'http://www.cellpress.com/ \n', 'http://www.cd
# ...
